# %%
import pandas as pd

# %%
market_data = pd.read_csv("data/market_data.csv")
market_data.head()
# Out:
#         Price               Close             Close.1             Close.2  \
# 0      Ticker                AAPL                 SPY                TSLA
# 1        Date                 NaN                 NaN                 NaN
# 2  2024-01-02  183.56219482421875   459.9911804199219   248.4199981689453
# 3  2024-01-03  182.18777465820312  456.23455810546875   238.4499969482422
# 4  2024-01-04  179.87393188476562   454.7650146484375  237.92999267578125
#
#                  High              High.1              High.2  \
# 0                AAPL                 SPY                TSLA
# 1                 NaN                 NaN                 NaN
# 2  186.33085840634024   460.9838811377681              251.25
# 3   183.7995356475199   458.5702737454352  245.67999267578125
# 4  181.04071720671112  458.34644746704663   242.6999969482422
#
#                   Low               Low.1               Low.2  \
# 0                AAPL                 SPY                TSLA
# ...

# %%
market_data.drop(1).reset_index(drop=True)
# Out:
#           Price               Close             Close.1             Close.2  \
# 0        Ticker                AAPL                 SPY                TSLA
# 1    2024-01-02  183.56219482421875   459.9911804199219   248.4199981689453
# 2    2024-01-03  182.18777465820312  456.23455810546875   238.4499969482422
# 3    2024-01-04  179.87393188476562   454.7650146484375  237.92999267578125
# 4    2024-01-05  179.15213012695312    455.387939453125  237.49000549316406
# ..          ...                 ...                 ...                 ...
# 247  2024-12-23      253.6494140625   586.1866455078125   430.6000061035156
# 248  2024-12-24   256.5608215332031      592.7021484375   462.2799987792969
# 249  2024-12-26   257.3756103515625   592.7415771484375   454.1300048828125
# 250  2024-12-27  253.96737670898438   586.5020751953125   431.6600036621094
# 251  2024-12-30  250.59889221191406     579.80908203125   417.4100036621094
#
# ...

# %%
market_data.to_json("data/market_data.json")

# %%
market_data_json = pd.read_json("data/market_data.json")
market_data_json.head()
# Out:
#         Price               Close             Close.1             Close.2  \
# 0      Ticker                AAPL                 SPY                TSLA
# 1        Date                None                None                None
# 2  2024-01-02  183.56219482421875   459.9911804199219   248.4199981689453
# 3  2024-01-03  182.18777465820312  456.23455810546875   238.4499969482422
# 4  2024-01-04  179.87393188476562   454.7650146484375  237.92999267578125
#
#                  High              High.1              High.2  \
# 0                AAPL                 SPY                TSLA
# 1                None                None                None
# 2  186.33085840634024   460.9838811377681              251.25
# 3   183.7995356475199   458.5702737454352  245.67999267578125
# 4  181.04071720671112  458.34644746704663   242.6999969482422
#
#                   Low               Low.1               Low.2  \
# 0                AAPL                 SPY                TSLA
# ...

# %%
import yfinance as yf 
aapl = yf.download("AAPL", start="2024-01-01", end="2024-12-31")

aapl.to_csv("data/aapl.csv")
pd.read_csv("data/aapl.csv").head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#         Price               Close                High                 Low  \
# 0      Ticker                AAPL                AAPL                AAPL
# 1        Date                 NaN                 NaN                 NaN
# 2  2024-01-02   183.5622100830078   186.3308738952772  181.83179708633995
# 3  2024-01-03    182.187744140625  183.79950485996184  181.37691491631995
# 4  2024-01-04  179.87393188476562  181.04071720671112  178.85546161628733
#
#                  Open    Volume
# 0                AAPL      AAPL
# 1                 NaN       NaN
# 2  185.05530386559408  82488700
# 3  182.15808112880916  58414500
# 4  180.11123597031312  71983600
